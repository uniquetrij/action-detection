# %%
from dataset import DataLoader, LabeledPathListingGenerator, DataSet
from matplotlib import pyplot as plt
# label_generator = LabelGenerator("dataset", ['avi'])
# data_loader = label_generator.gnerate_labels("video_label.pkl", "label_encoding.pkl")


data_loader = DataLoader("video_label.pkl", "label_encoding.pkl")
train_set, val_set, test_set = data_loader.generate_split([0.7,0.2,0.1])
# train_set.preprocess(frame_count=50)
train_set.preprocess(frame_count=50, resize_width=224, resize_height=224)

generator = train_set.get_batch_generator(2)
# Out:
# Frame Shape (240, 320, 3)
# Frame Shape (240, 320, 3)
# Frame Shape (240, 320, 3)

# %%
example = next(generator)
# example = generator
# train_set.width

# %%
print(example[0].shape)
print(example[0][0].shape)
# Out:
# (2, 50, 240, 320, 3)
# (50, 240, 320, 3)

# %%
import numpy as np
print(example[0][0][0].shape)
# a = np.reshape(example[0][0][0], (224, 224))
# print(a.shape)
plt.imshow(example[0][0][0])
# Out:
# (240, 320, 3)

# %%
from keras.utils import np_utils, generic_utils
from keras.layers.convolutional import Conv3D
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Flatten, Dense, Lambda, Cropping2D, Activation, Dropout
from keras.layers.convolutional import Convolution3D
from keras.layers.pooling import MaxPooling3D

def build_model(class_count, frame_count, width, height):
    model = Sequential()

    model.add(Conv3D(1, kernel_size=(3, 7, 7), input_shape=(frame_count, height, width, 1), activation='relu'))
    model.add(MaxPooling3D(pool_size=(3, 3, 3)))
    model.add(Dropout(0.75))

    # model.add(Conv3D(64, kernel_size=(3, 7, 7), activation='relu' ))
    # model.add(Dropout(0.75))
    # 
    # model.add(Conv3D(128, kernel_size=(1 ,7, 7), activation='relu' ))
    # model.add(Dropout(0.5))
    # 
    # model.add(Conv3D(256, kernel_size=(1, 7, 7), activation='relu' ))
    # model.add(Dropout(0.5))

    model.add(Flatten())

    # model.add(Dense(128, init='normal', activation='relu'))
    # model.add(Dropout(0.75))

    model.add(Dense(class_count, init='normal'))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    model.summary()

    return model;
# Out:
# Using TensorFlow backend.

# %%
frame_count = 50
batch_size = 10
class_count = 2
from i3d_inception import Inception_Inflated3d
print(train_set.get_shape())
model = Inception_Inflated3d(classes=class_count, input_shape=(train_set.get_shape()))

model.summary()
# Out:
# Using TensorFlow backend.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 50, 224, 224, 0
# __________________________________________________________________________________________________
# Conv3d_1a_7x7_conv (Conv3D)     (None, 25, 112, 112, 65856       input_1[0][0]
# __________________________________________________________________________________________________
# Conv3d_1a_7x7_bn (BatchNormaliz (None, 25, 112, 112, 192         Conv3d_1a_7x7_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_1a_7x7 (Activation)      (None, 25, 112, 112, 0           Conv3d_1a_7x7_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_2a_3x3 (MaxPooling3D) (None, 25, 56, 56, 6 0           Conv3d_1a_7x7[0][0]
# __________________________________________________________________________________________________
# Conv3d_2b_1x1_conv (Conv3D)     (None, 25, 56, 56, 6 4096        MaxPool2d_2a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_2b_1x1_bn (BatchNormaliz (None, 25, 56, 56, 6 192         Conv3d_2b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_2b_1x1 (Activation)      (None, 25, 56, 56, 6 0           Conv3d_2b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_2c_3x3_conv (Conv3D)     (None, 25, 56, 56, 1 331776      Conv3d_2b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_2c_3x3_bn (BatchNormaliz (None, 25, 56, 56, 1 576         Conv3d_2c_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_2c_3x3 (Activation)      (None, 25, 56, 56, 1 0           Conv3d_2c_3x3_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_3a_3x3 (MaxPooling3D) (None, 25, 28, 28, 1 0           Conv3d_2c_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1a_1x1_conv (Conv3D)  (None, 25, 28, 28, 9 18432       MaxPool2d_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2a_1x1_conv (Conv3D)  (None, 25, 28, 28, 1 3072        MaxPool2d_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1a_1x1_bn (BatchNorma (None, 25, 28, 28, 9 288         Conv3d_3b_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2a_1x1_bn (BatchNorma (None, 25, 28, 28, 1 48          Conv3d_3b_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1a_1x1 (Activation)   (None, 25, 28, 28, 9 0           Conv3d_3b_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2a_1x1 (Activation)   (None, 25, 28, 28, 1 0           Conv3d_3b_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_3b_3a_3x3 (MaxPooling (None, 25, 28, 28, 1 0           MaxPool2d_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_0a_1x1_conv (Conv3D)  (None, 25, 28, 28, 6 12288       MaxPool2d_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1b_3x3_conv (Conv3D)  (None, 25, 28, 28, 1 331776      Conv3d_3b_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2b_3x3_conv (Conv3D)  (None, 25, 28, 28, 3 13824       Conv3d_3b_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_3b_1x1_conv (Conv3D)  (None, 25, 28, 28, 3 6144        MaxPool2d_3b_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_0a_1x1_bn (BatchNorma (None, 25, 28, 28, 6 192         Conv3d_3b_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1b_3x3_bn (BatchNorma (None, 25, 28, 28, 1 384         Conv3d_3b_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2b_3x3_bn (BatchNorma (None, 25, 28, 28, 3 96          Conv3d_3b_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_3b_1x1_bn (BatchNorma (None, 25, 28, 28, 3 96          Conv3d_3b_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_0a_1x1 (Activation)   (None, 25, 28, 28, 6 0           Conv3d_3b_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1b_3x3 (Activation)   (None, 25, 28, 28, 1 0           Conv3d_3b_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2b_3x3 (Activation)   (None, 25, 28, 28, 3 0           Conv3d_3b_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_3b_1x1 (Activation)   (None, 25, 28, 28, 3 0           Conv3d_3b_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_3b (Concatenate)          (None, 25, 28, 28, 2 0           Conv3d_3b_0a_1x1[0][0]
#                                                                  Conv3d_3b_1b_3x3[0][0]
#                                                                  Conv3d_3b_2b_3x3[0][0]
#                                                                  Conv3d_3b_3b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1a_1x1_conv (Conv3D)  (None, 25, 28, 28, 1 32768       Mixed_3b[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2a_1x1_conv (Conv3D)  (None, 25, 28, 28, 3 8192        Mixed_3b[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1a_1x1_bn (BatchNorma (None, 25, 28, 28, 1 384         Conv3d_3c_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2a_1x1_bn (BatchNorma (None, 25, 28, 28, 3 96          Conv3d_3c_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1a_1x1 (Activation)   (None, 25, 28, 28, 1 0           Conv3d_3c_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2a_1x1 (Activation)   (None, 25, 28, 28, 3 0           Conv3d_3c_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_3c_3a_3x3 (MaxPooling (None, 25, 28, 28, 2 0           Mixed_3b[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_0a_1x1_conv (Conv3D)  (None, 25, 28, 28, 1 32768       Mixed_3b[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1b_3x3_conv (Conv3D)  (None, 25, 28, 28, 1 663552      Conv3d_3c_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2b_3x3_conv (Conv3D)  (None, 25, 28, 28, 9 82944       Conv3d_3c_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_3b_1x1_conv (Conv3D)  (None, 25, 28, 28, 6 16384       MaxPool2d_3c_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_0a_1x1_bn (BatchNorma (None, 25, 28, 28, 1 384         Conv3d_3c_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1b_3x3_bn (BatchNorma (None, 25, 28, 28, 1 576         Conv3d_3c_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2b_3x3_bn (BatchNorma (None, 25, 28, 28, 9 288         Conv3d_3c_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_3b_1x1_bn (BatchNorma (None, 25, 28, 28, 6 192         Conv3d_3c_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_0a_1x1 (Activation)   (None, 25, 28, 28, 1 0           Conv3d_3c_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1b_3x3 (Activation)   (None, 25, 28, 28, 1 0           Conv3d_3c_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2b_3x3 (Activation)   (None, 25, 28, 28, 9 0           Conv3d_3c_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_3b_1x1 (Activation)   (None, 25, 28, 28, 6 0           Conv3d_3c_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_3c (Concatenate)          (None, 25, 28, 28, 4 0           Conv3d_3c_0a_1x1[0][0]
#                                                                  Conv3d_3c_1b_3x3[0][0]
#                                                                  Conv3d_3c_2b_3x3[0][0]
#                                                                  Conv3d_3c_3b_1x1[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_4a_3x3 (MaxPooling3D) (None, 13, 14, 14, 4 0           Mixed_3c[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1a_1x1_conv (Conv3D)  (None, 13, 14, 14, 9 46080       MaxPool2d_4a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2a_1x1_conv (Conv3D)  (None, 13, 14, 14, 1 7680        MaxPool2d_4a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1a_1x1_bn (BatchNorma (None, 13, 14, 14, 9 288         Conv3d_4b_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2a_1x1_bn (BatchNorma (None, 13, 14, 14, 1 48          Conv3d_4b_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1a_1x1 (Activation)   (None, 13, 14, 14, 9 0           Conv3d_4b_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2a_1x1 (Activation)   (None, 13, 14, 14, 1 0           Conv3d_4b_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_4b_3a_3x3 (MaxPooling (None, 13, 14, 14, 4 0           MaxPool2d_4a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_0a_1x1_conv (Conv3D)  (None, 13, 14, 14, 1 92160       MaxPool2d_4a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1b_3x3_conv (Conv3D)  (None, 13, 14, 14, 2 539136      Conv3d_4b_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2b_3x3_conv (Conv3D)  (None, 13, 14, 14, 4 20736       Conv3d_4b_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_3b_1x1_conv (Conv3D)  (None, 13, 14, 14, 6 30720       MaxPool2d_4b_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_0a_1x1_bn (BatchNorma (None, 13, 14, 14, 1 576         Conv3d_4b_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1b_3x3_bn (BatchNorma (None, 13, 14, 14, 2 624         Conv3d_4b_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2b_3x3_bn (BatchNorma (None, 13, 14, 14, 4 144         Conv3d_4b_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_3b_1x1_bn (BatchNorma (None, 13, 14, 14, 6 192         Conv3d_4b_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_0a_1x1 (Activation)   (None, 13, 14, 14, 1 0           Conv3d_4b_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1b_3x3 (Activation)   (None, 13, 14, 14, 2 0           Conv3d_4b_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2b_3x3 (Activation)   (None, 13, 14, 14, 4 0           Conv3d_4b_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_3b_1x1 (Activation)   (None, 13, 14, 14, 6 0           Conv3d_4b_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_4b (Concatenate)          (None, 13, 14, 14, 5 0           Conv3d_4b_0a_1x1[0][0]
#                                                                  Conv3d_4b_1b_3x3[0][0]
#                                                                  Conv3d_4b_2b_3x3[0][0]
#                                                                  Conv3d_4b_3b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_1a_1x1_conv (Conv3D)  (None, 13, 14, 14, 1 57344       Mixed_4b[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_2a_1x1_conv (Conv3D)  (None, 13, 14, 14, 2 12288       Mixed_4b[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c
0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_1b_3x3_conv (Conv3D)  (None, 13, 14, 14, 3 1382400     Conv3d_4f_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_2b_3x3_conv (Conv3D)  (None, 13, 14, 14, 1 110592      Conv3d_4f_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_3b_1x1_conv (Conv3D)  (None, 13, 14, 14, 1 67584       MaxPool2d_4f_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_0a_1x1_bn (BatchNorma (None, 13, 14, 14, 2 768         Conv3d_4f_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_1b_3x3_bn (BatchNorma (None, 13, 14, 14, 3 960         Conv3d_4f_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_2b_3x3_bn (BatchNorma (None, 13, 14, 14, 1 384         Conv3d_4f_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_3b_1x1_bn (BatchNorma (None, 13, 14, 14, 1 384         Conv3d_4f_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_0a_1x1 (Activation)   (None, 13, 14, 14, 2 0           Conv3d_4f_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_1b_3x3 (Activation)   (None, 13, 14, 14, 3 0           Conv3d_4f_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_2b_3x3 (Activation)   (None, 13, 14, 14, 1 0           Conv3d_4f_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_3b_1x1 (Activation)   (None, 13, 14, 14, 1 0           Conv3d_4f_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_4f (Concatenate)          (None, 13, 14, 14, 8 0           Conv3d_4f_0a_1x1[0][0]
#                                                                  Conv3d_4f_1b_3x3[0][0]
#                                                                  Conv3d_4f_2b_3x3[0][0]
#                                                                  Conv3d_4f_3b_1x1[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_5a_2x2 (MaxPooling3D) (None, 7, 7, 7, 832) 0           Mixed_4f[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1a_1x1_conv (Conv3D)  (None, 7, 7, 7, 160) 133120      MaxPool2d_5a_2x2[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2a_1x1_conv (Conv3D)  (None, 7, 7, 7, 32)  26624       MaxPool2d_5a_2x2[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1a_1x1_bn (BatchNorma (None, 7, 7, 7, 160) 480         Conv3d_5b_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2a_1x1_bn (BatchNorma (None, 7, 7, 7, 32)  96          Conv3d_5b_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1a_1x1 (Activation)   (None, 7, 7, 7, 160) 0           Conv3d_5b_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2a_1x1 (Activation)   (None, 7, 7, 7, 32)  0           Conv3d_5b_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_5b_3a_3x3 (MaxPooling (None, 7, 7, 7, 832) 0           MaxPool2d_5a_2x2[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_0a_1x1_conv (Conv3D)  (None, 7, 7, 7, 256) 212992      MaxPool2d_5a_2x2[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1b_3x3_conv (Conv3D)  (None, 7, 7, 7, 320) 1382400     Conv3d_5b_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2b_3x3_conv (Conv3D)  (None, 7, 7, 7, 128) 110592      Conv3d_5b_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_3b_1x1_conv (Conv3D)  (None, 7, 7, 7, 128) 106496      MaxPool2d_5b_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_0a_1x1_bn (BatchNorma (None, 7, 7, 7, 256) 768         Conv3d_5b_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1b_3x3_bn (BatchNorma (None, 7, 7, 7, 320) 960         Conv3d_5b_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2b_3x3_bn (BatchNorma (None, 7, 7, 7, 128) 384         Conv3d_5b_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_3b_1x1_bn (BatchNorma (None, 7, 7, 7, 128) 384         Conv3d_5b_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_0a_1x1 (Activation)   (None, 7, 7, 7, 256) 0           Conv3d_5b_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1b_3x3 (Activation)   (None, 7, 7, 7, 320) 0           Conv3d_5b_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2b_3x3 (Activation)   (None, 7, 7, 7, 128) 0           Conv3d_5b_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_3b_1x1 (Activation)   (None, 7, 7, 7, 128) 0           Conv3d_5b_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_5b (Concatenate)          (None, 7, 7, 7, 832) 0           Conv3d_5b_0a_1x1[0][0]
#                                                                  Conv3d_5b_1b_3x3[0][0]
#                                                                  Conv3d_5b_2b_3x3[0][0]
#                                                                  Conv3d_5b_3b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1a_1x1_conv (Conv3D)  (None, 7, 7, 7, 192) 159744      Mixed_5b[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2a_1x1_conv (Conv3D)  (None, 7, 7, 7, 48)  39936       Mixed_5b[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1a_1x1_bn (BatchNorma (None, 7, 7, 7, 192) 576         Conv3d_5c_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2a_1x1_bn (BatchNorma (None, 7, 7, 7, 48)  144         Conv3d_5c_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1a_1x1 (Activation)   (None, 7, 7, 7, 192) 0           Conv3d_5c_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2a_1x1 (Activation)   (None, 7, 7, 7, 48)  0           Conv3d_5c_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_5c_3a_3x3 (MaxPooling (None, 7, 7, 7, 832) 0           Mixed_5b[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_0a_1x1_conv (Conv3D)  (None, 7, 7, 7, 384) 319488      Mixed_5b[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1b_3x3_conv (Conv3D)  (None, 7, 7, 7, 384) 1990656     Conv3d_5c_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2b_3x3_conv (Conv3D)  (None, 7, 7, 7, 128) 165888      Conv3d_5c_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_3b_1x1_conv (Conv3D)  (None, 7, 7, 7, 128) 106496      MaxPool2d_5c_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_0a_1x1_bn (BatchNorma (None, 7, 7, 7, 384) 1152        Conv3d_5c_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1b_3x3_bn (BatchNorma (None, 7, 7, 7, 384) 1152        Conv3d_5c_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2b_3x3_bn (BatchNorma (None, 7, 7, 7, 128) 384         Conv3d_5c_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_3b_1x1_bn (BatchNorma (None, 7, 7, 7, 128) 384         Conv3d_5c_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_0a_1x1 (Activation)   (None, 7, 7, 7, 384) 0           Conv3d_5c_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1b_3x3 (Activation)   (None, 7, 7, 7, 384) 0           Conv3d_5c_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2b_3x3 (Activation)   (None, 7, 7, 7, 128) 0           Conv3d_5c_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_3b_1x1 (Activation)   (None, 7, 7, 7, 128) 0           Conv3d_5c_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_5c (Concatenate)          (None, 7, 7, 7, 1024 0           Conv3d_5c_0a_1x1[0][0]
#                                                                  Conv3d_5c_1b_3x3[0][0]
#                                                                  Conv3d_5c_2b_3x3[0][0]
#                                                                  Conv3d_5c_3b_1x1[0][0]
# __________________________________________________________________________________________________
# global_avg_pool (AveragePooling (None, 6, 1, 1, 1024 0           Mixed_5c[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 6, 1, 1, 1024 0           global_avg_pool[0][0]
# __________________________________________________________________________________________________
# Conv3d_6a_1x1_conv (Conv3D)     (None, 6, 1, 1, 2)   2050        dropout_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 6, 2)         0           Conv3d_6a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 2)            0           reshape_1[0][0]
# ==================================================================================================
# Total params: 12,296,594
# Trainable params: 12,282,034
# Non-trainable params: 14,560
# __________________________________________________________________________________________________

# %%
hist = model.fit_generator(train_set.get_batch_generator(batch_size,frame_count),
                       validation_data=val_set.get_batch_generator(batch_size,frame_count),
                       epochs=10,
                              steps_per_epoch=train_set.size/batch_size,
                              validation_steps=val_set.size/batch_size)
# Out:
# Epoch 1/10
